# %%
#import all the necessary libraries

import numpy as np
import pandas as pd

 

# for visual
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import and read file
df = pd.read_csv(r"D:\OneDrive\Documents\RESERVED\PERSONAL\COMPUTER TRAININGS\QUANTUM FOLDER\DAF\QA DAF FILES\PYTHON FILES\Unicorn_Companies.csv") #for csv file, pd.read_excel() #for excel, #for json, pd.read_json
df
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
#head of the data
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
#tail of the data
df.tail()
# Out:
#           Company Valuation Date Joined                         Industry  \
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#             City         Country      Continent  Year Founded Funding  \
# 1069    Shanghai           China           Asia          2012   $379M
# 1070     Beijing           China           Asia          2015   $990M
# 1071   Chongqing           China           Asia          2018    $80M
# 1072      London  United Kingdom         Europe          2005   $792M
# 1073  Long Beach   United States  North America          2014   $620M
#
#                                        Select Investors
# ...

# %%
#Shape of the data
df.shape
# Out:
# (1074, 10)

# %%
#info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
#check for missing value
df.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# dtype: int64

# %%
# visualize missing value using heatmap
plt.figure(figsize = (12, 6))
sns.heatmap(df.isnull(), cbar = True, cmap = 'cool')
plt.title('Visualizing missing values')
plt.show()

# %%
#check columns
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
# value counts for categorical variables

import pandas as pd

# %%
# check the columns that are categorical and numerical columns
numerical_cols = df.select_dtypes(include = ['int64', 'float64']).columns.tolist()
numerical_cols
# Out:
# ['Year Founded']

# %%
# check the columns that are categorical and numerical columns
categorical_cols = df.select_dtypes(include = ['object', 'category']).columns.tolist()
categorical_cols
# Out:
# ['Company',
#  'Valuation',
#  'Date Joined',
#  'Industry',
#  'City',
#  'Country',
#  'Continent',
#  'Funding',
#  'Select Investors']

# %%
# value counts for categorical variables

for column in categorical_cols:

    print(df[column].value_counts())
# Out:
# Bolt               2
# Bytedance          1
# Yidian Zixun       1
# Klook              1
# Epirus             1
#                   ..
# eDaili             1
# ENOVATE            1
# Fenbi Education    1
# Hesai Tech         1
# Zwift              1
# Name: Company, Length: 1073, dtype: int64
# $1B      471
# $2B      248
# $3B      115
# $4B       72
# $5B       40
# $6B       26
# $7B       18
# $10B      15
# $8B       13
# $9B       10
# $12B      10
# $11B       7
# $13B       4
# $15B       4
# $100B      2
# $20B       2
# $32B       2
# $38B       2
# $40B       2
# $17B       1
# $14B       1
# $18B       1
# $22B       1
# $25B       1
# $27B       1
# $33B       1
# $39B       1
# $46B       1
# $95B       1
# $180B      1
# Name: Valuation, dtype: int64
# 2021-07-13    9
# 2021-09-15    7
# 2021-11-10    7
# 2022-02-22    7
# 2021-10-28    6
#              ..
# 2021-02-19    1
# 2021-08-12    1
# 2020-05-05    1
# 2015-04-14    1
# 2020-09-16    1
# ...

# %%
# value counts for numerical variables

for column in numerical_cols:

    print(df[column].value_counts())
# Out:
# 2015    155
# 2016    110
# 2014    109
# 2012     95
# 2013     87
# 2011     82
# 2017     74
# 2018     61
# 2019     45
# 2010     40
# 2009     34
# 2008     27
# 2020     25
# 2007     24
# 2006     15
# 2005     14
# 2021     11
# 2000     11
# 2001      9
# 1999      8
# 2004      8
# 2003      8
# 1998      5
# 2002      4
# 1994      2
# 1995      2
# 1996      1
# 1919      1
# 1991      1
# 1979      1
# 1992      1
# 1984      1
# 1990      1
# 1993      1
# 1997      1
# Name: Year Founded, dtype: int64

# %%
#check the descriptive statistics
df.describe().astype('int')
# Out:
#        Year Founded
# count          1074
# mean           2012
# std               5
# min            1919
# 25%            2011
# 50%            2014
# 75%            2016
# max            2021

# %%
import pandas as pd

# Load your dataset into a DataFrame (replace 'your_data.csv' with your dataset file)
df = pd.read_csv("D:/OneDrive/Documents/RESERVED/PERSONAL/COMPUTER TRAININGS/QUANTUM FOLDER/DAF/QA DAF FILES/PYTHON FILES/Unicorn_Companies.csv")

# Display basic information about the dataset
print(df.info())

# Handling Missing Values:
# 1. Drop rows with missing values
df.dropna(inplace=True)

# 2. Fill missing values with a specific value (e.g., fill NaN in a numeric column with the mean)
if 'numerical_cols' in df.columns:
    df['numerical_cols'].fillna(df['numerical_cols'].mean(), inplace=True)

# 3. Fill missing values in a categorical column with the most frequent value
if 'categorical_cols' in df.columns:
    df['categorical_cols'].fillna(df['categorical_cols'].mode()[0], inplace=True)

# Data Integrity:
# 4. Remove duplicate rows
df.drop_duplicates(inplace=True)

# 5. Set appropriate data types for columns
# Replace 'Date_Column' and 'numerical_col' with actual column names
if 'Year Founded' in df.columns:
    df['Year Founded'] = pd.to_datetime(df['Year Founded'])
if 'numerical_cols' in df.columns:
    df['numerical_cols'] = pd.to_numeric(df['numerical_cols'])


# 8. Set the index to a unique identifier column if applicable
# Replace 'Unique_ID_Column' with the actual column name
if 'Unique_ID_Column' in df.columns:
    df.set_index('Unique_ID_Column', inplace=True)

# Final Dataset Info after Data Cleaning:
print(df.info())

# Save the cleaned dataset to a new CSV file
df.to_csv("D:/OneDrive/Documents/RESERVED/PERSONAL/COMPUTER TRAININGS/QUANTUM FOLDER/DAF/QA DAF FILES/PYTHON FILES/Cleaned_Unicorn_Companies.csv", index=False)

# Return the cleaned DataFrame (optional)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1057 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
# ...

# %%
# Convert Valuation and Funding columns to numerical values
df['Valuation'] = df['Valuation'].str.extract('(\d+.\d+)').astype(float)
df['Funding'] = df['Funding'].str.extract('(\d+.\d+)').astype(float)

# Calculate the ROI as the ratio of Valuation to Funding
df['ROI'] = df['Valuation'] / df['Funding']

# Sort the DataFrame by ROI in descending order to find the companies with the highest ROI
top_companies_by_roi = df.sort_values(by='ROI', ascending=False)

# Display the top companies with the highest ROI
print(top_companies_by_roi[['Company', 'Valuation', 'Funding', 'ROI']])

# Additional analysis to identify factors contributing to their success
# You can analyze other columns like Industry, City, Country, Select Investors, etc., to find common trends or patterns among top companies.
# Out:
#           Company  Valuation  Funding  ROI
# 0       Bytedance      180.0      NaN  NaN
# 1          SpaceX      100.0      NaN  NaN
# 2           SHEIN      100.0      NaN  NaN
# 3          Stripe        NaN      NaN  NaN
# 4          Klarna        NaN      NaN  NaN
# ...           ...        ...      ...  ...
# 1069     Zhaogang        NaN    379.0  NaN
# 1070  Zhuan Zhuan        NaN    990.0  NaN
# 1071     Zihaiguo        NaN      NaN  NaN
# 1072         Zopa        NaN    792.0  NaN
# 1073        Zwift        NaN    620.0  NaN
#
# [1057 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your cleaned dataset into a DataFrame
df = pd.read_csv("D:/OneDrive/Documents/RESERVED/PERSONAL/COMPUTER TRAININGS/QUANTUM FOLDER/DAF/QA DAF FILES/PYTHON FILES/Cleaned_Unicorn_Companies.csv")

# Check if the columns exist in the DataFrame before using them
if 'ROI' in df.columns:
    # Identify companies with the highest ROI
    top_companies_by_roi = df.sort_values(by='ROI', ascending=False)
    print("Companies with the Highest ROI:")
    print(top_companies_by_roi[['Company', 'ROI']].head())

if 'Time to Unicorn' in df.columns:
    # Analyze trends in the time it takes to become a unicorn
    average_time_to_unicorn = df['Time to Unicorn'].mean()
    print(f"\nAverage Time to Unicorn: {average_time_to_unicorn:.2f} days")

    # You can also visualize the distribution of time to unicorn using a histogram
    if 'Time to Unicorn' in df.columns:
        plt.figure(figsize=(8, 6))
        plt.hist(df['Time to Unicorn'], bins=20, color='skyblue')
        plt.xlabel('Time to Unicorn (Days)')
        plt.ylabel('Number of Companies')
        plt.title('Distribution of Time to Unicorn')
        plt.show()

if 'Industry' in df.columns:
    # Determine which industries are most represented
    industry_counts = df['Industry'].value_counts()
    print("\nIndustries with the Most Unicorn Companies:")
    print(industry_counts)

    # You can visualize the distribution of industries
    plt.figure(figsize=(10, 6))
    industry_counts.plot(kind='bar', color='blue')
    plt.xlabel('Industry')
    plt.ylabel('Number of Companies')
    plt.title('Unicorn Companies by Industry')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# Industries with the Most Unicorn Companies:
# Fintech                                218
# Internet software & services           203
# E-commerce & direct-to-consumer        107
# Health                                  74
# Artificial intelligence                 71
# Other                                   58
# Supply chain, logistics, & delivery     56
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             36
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Artificial Intelligence                 11
# Name: Industry, dtype: int64

# %%
# Convert 'Year Founded' and 'Date Joined' columns to datetime objects
df['Year Founded'] = pd.to_datetime(df['Year Founded'], format='%Y')
df['Date Joined'] = pd.to_datetime(df['Date Joined'])

# Calculate the time it takes for a company to become a unicorn
df['Time to Unicorn'] = (df['Date Joined'] - df['Year Founded']).dt.days

# Calculate the average time to unicorn
average_time_to_unicorn = df['Time to Unicorn'].mean()

# Print the average time to unicorn
print(f"Average Time to Unicorn: {average_time_to_unicorn:.2f} days")

# You can also visualize the distribution of time to unicorn using a histogram
import matplotlib.pyplot as plt

plt.hist(df['Time to Unicorn'], bins=20)
plt.xlabel('Time to Unicorn (Days)')
plt.ylabel('Number of Companies')
plt.title('Distribution of Time to Unicorn')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Convert 'Year Founded' and 'Date Joined' columns to datetime objects
# ----> 2 df['Year Founded'] = pd.to_datetime(df['Year Founded'], format='%Y')
#       3 df['Date Joined'] = pd.to_datetime(df['Date Joined'])
#       5 # Calculate the time it takes for a company to become a unicorn
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1064, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1062             result = arg.tz_localize(tz)
#    1063 elif isinstance(arg, ABCSeries):
# -> 1064     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1065     if not cache_array.empty:
#    1066         result = arg.map(cache_array)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group the DataFrame by 'Country' and count the number of unicorn companies in each country
country_counts = df['Country'].value_counts()

# Display the countries with the most unicorn companies
print("Countries with the Most Unicorn Companies:")
print(country_counts.head())

# You can also visualize the top countries with the most unicorn companies
plt.figure(figsize=(10, 6))
country_counts.head(10).plot(kind='bar', color='skyblue')
plt.xlabel('Country')
plt.ylabel('Number of Unicorn Companies')
plt.title('Top Countries with the Most Unicorn Companies')
plt.show()

# Group the DataFrame by 'City' and count the number of unicorn companies in each city
city_counts = df['City'].value_counts()

# Display the cities with the most unicorn companies
print("\nCities with the Most Unicorn Companies:")
print(city_counts.head())

# You can also visualize the top cities with the most unicorn companies
plt.figure(figsize=(10, 6))
city_counts.head(10).plot(kind='bar', color='lightcoral')
plt.xlabel('City')
plt.ylabel('Number of Unicorn Companies')
plt.title('Top Cities with the Most Unicorn Companies')
plt.show()
# Out:
# Countries with the Most Unicorn Companies:
# United States     562
# China             172
# India              65
# United Kingdom     43
# Germany            26
# Name: Country, dtype: int64
# Cities with the Most Unicorn Companies:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          43
# London            34
# Name: City, dtype: int64

# %%
import pandas as pd

# Split the 'Select Investors' column into a list of investors
df['Select Investors'] = df['Select Investors'].str.split(', ')

# Create a new DataFrame to store investor information
investor_df = df.explode('Select Investors')

# Group the investor DataFrame by investor and count the number of investments
investor_counts = investor_df['Select Investors'].value_counts()

# Display the investors who have funded the most unicorn companies
print("Investors with the Most Investments in Unicorn Companies:")
print(investor_counts.head())

# Evaluate the impact of their investments
# You can analyze the valuation or performance of companies funded by the top investors
top_investors = investor_counts.head(5).index  # Get the top 5 investors
investor_impact = df[df['Select Investors'].apply(lambda x: any(investor in top_investors for investor in x))]

# For example, you can display the valuation of companies funded by the top investors
print("\nImpact of Investments by Top Investors:")
print(investor_impact[['Company', 'Valuation', 'Select Investors']])
# Out:
# Investors with the Most Investments in Unicorn Companies:
# Accel                      59
# Andreessen Horowitz        52
# Tiger Global Management    52
# Insight Partners           47
# Sequoia Capital            46
# Name: Select Investors, dtype: int64
#
# Impact of Investments by Top Investors:
#                Company Valuation  \
# 2                SHEIN     $100B
# 4               Klarna      $46B
# 6         Checkout.com      $40B
# 8            JUUL Labs      $38B
# 9           Databricks      $38B
# ...                ...       ...
# 1038              Vise       $1B
# 1043         Watershed       $1B
# 1044  Weights & Biases       $1B
# 1046          Wrapbook       $1B
# 1047            Xendit       $1B
#
#                                        Select Investors
# 2     [Tiger Global Management, Sequoia Capital Chin...
# 4     [Institutional Venture Partners, Sequoia Capit...
# 6     [Tiger Global Management, Insight Partners, DS...
# ...

# %%
import pandas as pd

# Load your cleaned dataset into a DataFrame
df = pd.read_csv("D:/OneDrive/Documents/RESERVED/PERSONAL/COMPUTER TRAININGS/QUANTUM FOLDER/DAF/QA DAF FILES/PYTHON FILES/Cleaned_Unicorn_Companies.csv")

# Create a cross-tabulation table to analyze the relationship between 'Country' and 'Industry'
cross_tab = pd.crosstab(index=df['Country'], columns=df['Industry'])

# Display the cross-tabulation table
print("Cross-Tabulation of Country and Industry:")
print(cross_tab)

# You can also calculate the percentage of companies in each industry by country
cross_tab_percentage = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100

# Display the percentage table
print("\nPercentage of Companies in Each Industry by Country:")
print(cross_tab_percentage)

# Visualize the relationship using a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(cross_tab_percentage, annot=True, cmap="YlGnBu")
plt.xlabel('Industry')
plt.ylabel('Country')
plt.title('Relationship between Country and Industry')
plt.show()
# Out:
# Cross-Tabulation of Country and Industry:
# Industry              Artificial Intelligence  Artificial intelligence  \
# Country
# Argentina                                   0                        0
# Australia                                   0                        0
# Austria                                     0                        0
# Belgium                                     0                        0
# Bermuda                                     0                        1
# Brazil                                      0                        1
# Canada                                      0                        2
# Chile                                       1                        1
# China                                       4                       16
# Colombia                                    0                        0
# Croatia                                     0                        0
# ...

# %% [markdown]
# ## Actionable recommendations for stakeholders to focus on high-growth potential companies, diversify the investment portfolio, and prioritize experienced leadership teams to drive revenue and success:
#
# 1. **High-Growth Potential Companies**:
#    - **Industry Research**: Continuously monitor emerging industries and technologies with high growth potential, such as artificial intelligence, fintech, and e-commerce.
#    - **Scalability Assessment**: Evaluate companies based on their scalability potential, innovative technologies, and disruptive business models. Prioritize those with a significant addressable market.
#    - **Market Trends**: Keep a pulse on market trends and consumer behavior to identify companies that align with current and future demands.
#
# 2. **Diversify Investment Portfolio**:
#    - **Industry Diversification**: Ensure a diversified portfolio by investing in companies across various industries. This reduces risk and hedges against market fluctuations.
#    - **Geographical Spread**: Explore investments in companies from different regions and continents. This provides exposure to diverse markets and economic conditions.
#    - **Early-Stage and Mature Companies**: Diversify by including both early-stage startups with high growth potential and more established companies with stable revenues.
#
# 3. **Experienced Leadership Teams**:
#    - **Founder Background**: Prioritize companies with experienced founders and leadership teams who have a track record of successful ventures.
#    - **Management Due Diligence**: Conduct thorough due diligence on the management team's ability to execute the business plan and navigate challenges effectively.
#    - **Board of Directors**: Encourage companies to establish strong boards with industry experts and advisors who can provide strategic guidance.
#
# 4. **Continuous Data Analysis**:
#    - Implement regular data analysis and EDA to stay updated on performance and trends of portfolio companies.
#    - Utilize key performance indicators (KPIs) and metrics to assess the growth trajectory of each investment.
#    - Be ready to adapt investment strategies based on real-time data and market dynamics.
#
# 5. **Risk Mitigation**:
#    - Implement risk management strategies, such as diversification, hedging, and scenario analysis, to protect the investment portfolio from unexpected downturns.
#    - Establish clear exit strategies for underperforming investments.
#
# 6. **Collaboration and Networking**:
#    - Foster collaborations and partnerships with industry experts, other investors, and accelerators to gain insights and access to promising startups.
#    - Leverage collective intelligence and resources to enhance investment decision-making.
#
# 7. **Long-Term Perspective**:
#    - Encourage a long-term investment horizon. Unicorn companies often require time to reach their full potential.
#
# 8. **Adapt to Market Dynamics**:
#    - Stay agile and adapt to changing market conditions. Be prepared to pivot or adjust the investment strategy when necessary.
#
# 9. **Regulatory Compliance**:
#    - Ensure compliance with local and international regulations to mitigate legal and financial risks.
#
# 10. **Exit Strategies**:
#     - Develop clear exit strategies for portfolio companies, considering options like IPOs, acquisitions, or strategic partnerships.
#
# These recommendations aim to guide stakeholders in making informed decisions to drive revenue and success in the dynamic world of unicorn investments. Flexibility and continuous learning are key factors for sustainable growth and successful investment portfolios.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your cleaned dataset into a DataFrame
df = pd.read_csv("D:/OneDrive/Documents/RESERVED/PERSONAL/COMPUTER TRAININGS/QUANTUM FOLDER/DAF/QA DAF FILES/PYTHON FILES/Cleaned_Unicorn_Companies.csv")

# Univariate Analysis:
# 1. Distribution of Valuation
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Valuation', bins=20, kde=True)
plt.title('Distribution of Valuation')
plt.xlabel('Valuation')
plt.ylabel('Count')
plt.show()

# 2. Industry Counts
plt.figure(figsize=(10, 6))
df['Industry'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Counts of Companies by Industry')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# Bivariate Analysis:
# 3. Scatter plot between Valuation and Funding
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Valuation', y='Funding', hue='Industry', alpha=0.5)
plt.title('Scatter Plot of Valuation vs. Funding')
plt.xlabel('Valuation')
plt.ylabel('Funding')
plt.show()

# 4. Box plot of Valuation by Continent
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Continent', y='Valuation', palette='Set3')
plt.title('Box Plot of Valuation by Continent')
plt.xlabel('Continent')
plt.ylabel('Valuation')
plt.xticks(rotation=45)
plt.show()

# Multivariate Analysis:
# 5. Correlation Heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 37
#      35 # 4. Box plot of Valuation by Continent
#      36 plt.figure(figsize=(10, 6))
# ---> 37 sns.boxplot(data=df, x='Continent', y='Valuation', palette='Set3')
#      38 plt.title('Box Plot of Valuation by Continent')
#      39 plt.xlabel('Continent')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your cleaned dataset into a DataFrame
df = pd.read_csv("D:/OneDrive/Documents/RESERVED/PERSONAL/COMPUTER TRAININGS/QUANTUM FOLDER/DAF/QA DAF FILES/PYTHON FILES/Cleaned_Unicorn_Companies.csv")

# Create a scatter plot to analyze the relationship between Valuation and Funding
plt.figure(figsize=(8, 6))
plt.scatter(df['Funding'], df['Valuation'], alpha=0.5, color='blue')
plt.title('Scatter Plot of Valuation vs. Funding')
plt.xlabel('Funding')
plt.ylabel('Valuation')
plt.show()
